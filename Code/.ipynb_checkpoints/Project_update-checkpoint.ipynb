# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, accuracy_score, roc_auc_score, confusion_matrix, precision_recall_fscore_support
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing, neighbors

# %%
df = pd.read_csv(r'C:\Users\elaaf\Desktop\SDS\project_3_original_data\BitcoinHeistData.csv')
#df = pd.read_csv("/Users/muntaha/Documents/BitcoinHeistData.csv")

# %%
df.shape
# Out:
# (2916697, 10)

# %%
df.info(show_counts =True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2916697 entries, 0 to 2916696
# Data columns (total 10 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   address    2916697 non-null  object
#  1   year       2916697 non-null  int64
#  2   day        2916697 non-null  int64
#  3   length     2916697 non-null  int64
#  4   weight     2916697 non-null  float64
#  5   count      2916697 non-null  int64
#  6   looped     2916697 non-null  int64
#  7   neighbors  2916697 non-null  int64
#  8   income     2916697 non-null  float64
#  9   label      2916697 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 222.5+ MB

# %%
len(df.address.unique()) #the address is not unique
# Out:
# 2631095

# %%
plt.figure(figsize=(10,10));
sns.heatmap(df.corr(), annot=True);

# %% [markdown]
# ### Ransomware Distribution

# %%
to_plot = df.groupby(['label'])['address'].count().drop('white').sort_values(ascending=False)

# %%
to_plot
# Out:
# label
# paduaCryptoWall                12390
# montrealCryptoLocker            9315
# princetonCerber                 9223
# princetonLocky                  6625
# montrealCryptXXX                2419
# montrealNoobCrypt                483
# montrealDMALockerv3              354
# montrealDMALocker                251
# montrealSamSam                    62
# montrealGlobeImposter             55
# montrealCryptoTorLocker2015       55
# montrealGlobev3                   34
# montrealGlobe                     32
# montrealWannaCry                  28
# montrealRazy                      13
# montrealAPT                       11
# paduaKeRanger                     10
# montrealFlyper                     9
# montrealXTPLocker                  8
# montrealXLockerv5.0                7
# montrealCryptConsole               7
# montrealVenusLocker                7
# montrealEDA2                       6
# montrealJigSaw                     4
# paduaJigsaw                        2
# montrealSam                        1
# montrealXLocker                    1
# montrealComradeCircle              1
# Name: address, dtype: int64

# %%
to_plot[:10].plot(kind='barh',color=['lightpink','plum', 'mediumpurple','lightsteelblue']);

# %% [markdown]
# ### Changing labels to 0 and 1

# %%
unique_label = list(set(df.label))

# %%
d = {}

for i in unique_label:
    if i != 'white':
        d[i] = 1
    else:
        d[i] = 0

# %%
d
# Out:
# {'montrealGlobe': 1,
#  'montrealRazy': 1,
#  'montrealEDA2': 1,
#  'montrealGlobeImposter': 1,
#  'montrealXLocker': 1,
#  'paduaKeRanger': 1,
#  'montrealJigSaw': 1,
#  'montrealFlyper': 1,
#  'montrealSamSam': 1,
#  'montrealSam': 1,
#  'montrealComradeCircle': 1,
#  'montrealXLockerv5.0': 1,
#  'montrealCryptXXX': 1,
#  'paduaCryptoWall': 1,
#  'montrealWannaCry': 1,
#  'montrealAPT': 1,
#  'montrealDMALocker': 1,
#  'princetonLocky': 1,
#  'montrealVenusLocker': 1,
#  'white': 0,
#  'montrealCryptoLocker': 1,
#  'montrealGlobev3': 1,
#  'montrealCryptoTorLocker2015': 1,
#  'montrealDMALockerv3': 1,
#  'montrealCryptConsole': 1,
#  'montrealNoobCrypt': 1,
#  'montrealXTPLocker': 1,
#  'paduaJigsaw': 1,
#  'princetonCerber': 1}

# %%
df.label.replace(d, inplace=True)

# %%
labels_dist = df.groupby(['label'])['address'].count()
sns.barplot(y = labels_dist, x = [0,1])
# Out:
# <AxesSubplot:ylabel='address'>

# %%
labels_dist
# Out:
# label
# 0    2875284
# 1      41413
# Name: address, dtype: int64

# %%
df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2916697 entries, 0 to 2916696
# Data columns (total 10 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   address    2916697 non-null  object
#  1   year       2916697 non-null  int64
#  2   day        2916697 non-null  int64
#  3   length     2916697 non-null  int64
#  4   weight     2916697 non-null  float64
#  5   count      2916697 non-null  int64
#  6   looped     2916697 non-null  int64
#  7   neighbors  2916697 non-null  int64
#  8   income     2916697 non-null  float64
#  9   label      2916697 non-null  int64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 222.5+ MB
# C:\Users\elaaf\AppData\Local\Temp/ipykernel_9756/1982639406.py:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   df.info(null_counts=True)

# %%
fig = plt.figure(figsize = (10,7));
ax = fig.gca();
df.hist(ax = ax);
plt.tight_layout();
# Out:
# C:\Users\elaaf\AppData\Local\Temp/ipykernel_9756/1361211838.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df.hist(ax = ax);

# %% [markdown]
# ## Handeling Unbalanced Data

# %%
df_1 = df[(df['label']==1)]

# %%
df_1.shape
# Out:
# (41413, 10)

# %%
df_1.describe()
# Out:
#                year           day        length        weight         count  \
# count  41413.000000  41413.000000  41413.000000  4.141300e+04  41413.000000
# mean    2014.876923    174.439741     41.636926  6.274532e-01    599.810277
# std        1.361243     94.700239     58.442350  2.667625e+00   1419.955449
# min     2011.000000      1.000000      0.000000  4.719723e-42      1.000000
# 25%     2014.000000     90.000000      0.000000  6.250000e-02      1.000000
# 50%     2015.000000    160.000000      6.000000  3.880441e-01      1.000000
# 75%     2016.000000    260.000000     80.000000  1.000000e+00     15.000000
# max     2018.000000    365.000000    144.000000  4.982885e+02  13462.000000
#
#              looped     neighbors        income    label
# count  41413.000000  41413.000000  4.141300e+04  41413.0
# mean      95.100645      2.076256  7.833721e+08      1.0
# std      525.423306      2.401167  1.423362e+10      0.0
# min        0.000000      1.000000  3.000000e+07      1.0
# 25%        0.000000      1.000000  8.000000e+07      1.0
# 50%        0.000000      2.000000  1.250000e+08      1.0
# 75%        0.000000      2.000000  3.000000e+08      1.0
# max    11693.000000     94.000000  2.595000e+12      1.0

# %%
df_2 = df[(df['label']==0)].sample(n=41413, random_state=42)

# %%
df_2.shape
# Out:
# (41413, 10)

# %%
df_2.describe()
# Out:
#                year           day        length        weight         count  \
# count  41413.000000  41413.000000  41413.000000  4.141300e+04  41413.000000
# mean    2014.469080    182.330500     44.147538  5.861829e-01    717.606355
# std        2.270584    104.431949     58.681944  9.423326e+00   1698.990105
# min     2011.000000      1.000000      0.000000  6.493017e-80      1.000000
# 25%     2012.000000     92.000000      2.000000  2.371412e-02      1.000000
# 50%     2014.000000    183.000000      8.000000  2.500000e-01      1.000000
# 75%     2016.000000    272.000000     98.000000  9.062500e-01     53.000000
# max     2018.000000    365.000000    144.000000  1.866717e+03  14494.000000
#
#              looped     neighbors        income    label
# count  41413.000000  41413.000000  4.141300e+04  41413.0
# mean     240.033275      2.414121  3.816353e+09      0.0
# std      966.557317     58.450442  7.154849e+10      0.0
# min        0.000000      1.000000  3.000000e+07      0.0
# 25%        0.000000      1.000000  7.466611e+07      0.0
# 50%        0.000000      2.000000  2.000000e+08      0.0
# 75%        0.000000      2.000000  1.000000e+09      0.0
# max    13833.000000  11746.000000  1.067816e+13      0.0

# %%
df_new = pd.concat([df_1, df_2])

# %%
sns.set(rc={'figure.figsize':(5,5)})
labels_dist_ = df_new.groupby(['label'])['address'].count()
sns.barplot(y = labels_dist_, x = [0,1])
# Out:
# <AxesSubplot:ylabel='address'>

# %%
# sns.pairplot(df_new, hue='label');

# %%
#sns.pairplot(df_new);

# %%
fig = plt.figure(figsize = (10,7));
ax = fig.gca();
df_new.hist(ax = ax);
plt.tight_layout();
# Out:
# C:\Users\elaaf\AppData\Local\Temp/ipykernel_9756/3678586302.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df_new.hist(ax = ax);

# %%
sns.set(rc={'figure.figsize':(15,15)})
sns.heatmap(df_new.corr(), annot=True);

# %% [markdown]
# ### Fitting the model

# %%
X_train, X_test, y_train, y_test = train_test_split(df_new.drop(columns=['label','address']), df_new['label'], 
                                                    test_size = 0.25, random_state=42)

# %%
classifier = SGDClassifier(loss='log', max_iter=100) 
model = classifier.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
conf_mat = confusion_matrix(y_test,y_pred)
print("The accuracy of the model is :", round(accuracy,2)*100,"%")
print("Confusion Matrix:\n", conf_mat)
# Out:
# The accuracy of the model is : 50.0 %
# Confusion Matrix:
#  [[10339     0]
#  [10368     0]]

# %%
precision, recall, fscore, support = precision_recall_fscore_support(y_test, y_pred, average='binary')
print('Precision = ',round(precision,4),'\nRecall = ', round(recall,4), '\nF-Score = ',round(fscore,4))
# Out:
# Precision =  0.0
# Recall =  0.0
# F-Score =  0.0
# C:\Users\elaaf\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
classifier = SGDClassifier(loss='log', max_iter=100) 
model = classifier.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)

# %%
accuracy = accuracy_score(y_test,y_pred)
conf_mat = confusion_matrix(y_test,y_pred)
print("The accuracy of the model is :", round(accuracy,2)*100,"%")
print("Confusion Matrix:\n", conf_mat)
# Out:
# The accuracy of the model is : 60.0 %
# Confusion Matrix:
#  [[5478 4861]
#  [3427 6941]]

# %%
precision, recall, fscore, support = precision_recall_fscore_support(y_test, y_pred, average='binary')
print('Precision = ',round(precision,4),'\nRecall = ', round(recall,4), '\nF-Score = ',round(fscore,4))
# Out:
# Precision =  0.5881
# Recall =  0.6695
# F-Score =  0.6262

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
classifier = SGDClassifier(loss='log', max_iter=100) 
model = classifier.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)

# %%
accuracy = accuracy_score(y_test,y_pred)
conf_mat = confusion_matrix(y_test,y_pred)
print("The accuracy of the model is :", round(accuracy,2)*100,"%")
print("Confusion Matrix:\n", conf_mat)
# Out:
# The accuracy of the model is : 54.0 %
# Confusion Matrix:
#  [[6133 4206]
#  [5273 5095]]

# %%
precision, recall, fscore, support = precision_recall_fscore_support(y_test, y_pred, average='binary')
print('Precision = ',round(precision,4),'\nRecall = ', round(recall,4), '\nF-Score = ',round(fscore,4))
# Out:
# Precision =  0.5478
# Recall =  0.4914
# F-Score =  0.5181

# %%
#df_new.to_csv(r'C:\Users\elaaf\Desktop\SDS\Project_3\Data\BMT_balanced.csv')

# %% [markdown]
# # Pre-Processing

# %%
df_Temp = df.copy(deep=True)

# %%
#change address to numerical (preprocessing.LabelEncoder())
label_encoder = preprocessing.LabelEncoder()
df_Temp['address']=label_encoder.fit_transform(df_Temp['address'])
df_Temp.head()
# Out:
#    address  year  day  length    weight  count  looped  neighbors  \
# 0       23  2017   11      18  0.008333      1       0          2
# 1      128  2016  132      44  0.000244      1       0          1
# 2      169  2016  246       0  1.000000      1       0          2
# 3      217  2016  322      72  0.003906      1       0          2
# 4      293  2016  238     144  0.072848    456       0          1
#
#         income  label
# 0  100050000.0      1
# 1  100000000.0      1
# 2  200000000.0      1
# 3   71200000.0      1
# 4  200000000.0      1

# %%
#Median Encoding (Except day and year and address) - (Elaf)
#Mean Encoding (Except day and year)
#I think it's biased let's talk to miss nouras abt it

# %% [markdown]
# ## BoxCox

# %%
from scipy.stats import boxcox

# %%
fitted_data, fitted_lambda = boxcox(df_new['weight'])
df_new['new_weight'] = fitted_data

fig, ax = plt.subplots(1, 2)
sns.distplot(df_new['weight'], hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Non-Normal", color ="red", ax = ax[0]);

sns.distplot(fitted_data, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Normal", color ="green", ax = ax[1]);
# Out:
# C:\Users\elaaf\anaconda3\lib\site-packages\numpy\core\_methods.py:232: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# C:\Users\elaaf\anaconda3\lib\site-packages\numpy\core\_methods.py:243: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims=keepdims, where=where)
# C:\Users\elaaf\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\elaaf\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
fitted_data, fitted_lambda = boxcox(df_new['neighbors'])
df_new['new_neighbors'] = fitted_data

fig, ax = plt.subplots(1, 2)
sns.distplot(df_new['neighbors'], hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Non-Normal", color ="red", ax = ax[0]);

sns.distplot(fitted_data, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Normal", color ="green", ax = ax[1]);
# Out:
# C:\Users\elaaf\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\elaaf\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
fitted_data, fitted_lambda = boxcox(df_new['income'])
df_new['new_income'] = fitted_data

fig, ax = plt.subplots(1, 2)
sns.distplot(df_new['income'], hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Non-Normal", color ="red", ax = ax[0]);

sns.distplot(fitted_data, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Normal", color ="green", ax = ax[1]);
# Out:
# C:\Users\elaaf\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\elaaf\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
len(df_new[df_new['new_looped']>0].new_looped), len(fitted_data)
# Out:
# (75878, 10302)

# %%
len(np.empty_like(df_new['looped']))
# Out:
# 82826

# %%
fitted_data, fitted_lambda = boxcox(df_new[df_new['looped']>0].looped)

df_new['new_looped'] = np.empty_like(df_new['looped'])
df_new[df_new['new_looped']==0].new_looped = -1/fitted_lambda
df_new[df_new['new_looped']>0].new_looped = fitted_data



fig, ax = plt.subplots(1, 2)
sns.distplot(df_new['looped'], hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Non-Normal", color ="red", ax = ax[0]);

sns.distplot(fitted_data, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Normal", color ="green", ax = ax[1]);
# Out:
# C:\Users\elaaf\anaconda3\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9756/2340486973.py in <module>
#       3 df_new['new_looped'] = np.empty_like(df_new['looped'])
#       4 df_new[df_new['new_looped']==0].new_looped = -1/fitted_lambda
# ----> 5 df_new[df_new['new_looped']>0].new_looped = fitted_data
#       6
#       7
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5514                     object.__setattr__(self, name, value)
#    5515                 elif name in self._info_axis:
# -> 5516                     self[name] = value
#    5517                 else:
#    5518                     object.__setattr__(self, name, value)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3605         else:
#    3606             # set column
# -> 3607             self._set_item(key, value)
#    3608
#    3609     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3777         ensure homogeneity.
#    3778         """
# -> 3779         value = self._sanitize_column(value)
#    3780
#    3781         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4502
#    4503         if is_list_like(value):
# -> 4504             com.require_length_match(value, self.index)
#    4505         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4506
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     529     """
#     530     if len(data) != len(index):
# --> 531         raise ValueError(
#     532             "Length of values "
#     533             f"({len(data)}) "
#
# ValueError: Length of values (10302) does not match length of index (33)

# %%
fitted_data, fitted_lambda = boxcox(df_new[df_new['length']>0]['length'])
fig, ax = plt.subplots(1, 2)
sns.distplot(df_new['length'], hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Non-Normal", color ="red", ax = ax[0]);

sns.distplot(fitted_data, hist = False, kde = True,
            kde_kws = {'shade': True, 'linewidth': 2}, 
            label = "Normal", color ="green", ax = ax[1]);

# %% [markdown]
# # Handle Unbalanced Data

# %%
#above

# %% [markdown]
# # EDA

# %% [markdown]
# ### Unbalanced Data

# %%
# Heat Map
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True);

# %% [markdown]
# ### Balanced Data

# %%
# Heat Map
plt.figure(figsize=(10,10))
sns.heatmap(df_new.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df_Temp.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# pairplot
sns.pairplot(df_new, hue='label');

# %%
# Distribution

# %%
#Label count

# %%
#Ransomware and white distribution over years 
sns.displot(data=df_new, x="year", col="label", kind="kde");

# %% [markdown]
# ### SVM model

# %%
# Scale
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23136/2155922632.py in <module>
#       1 # Scale
#       2 scaler = MinMaxScaler()
# ----> 3 X_train_scaled = scaler.fit_transform(X_train)
#       4 X_test_scaled = scaler.fit_transform(X_test)
#
# NameError: name 'X_train' is not defined

# %%
# work on Balanced DATA (Random sampling)
model = SVC(kernel='rbf', random_state = 2)

# %%
model.fit(X_train, y_train)

# %%
Y_pred = model.predict(X_test)

# %%
Y_pred

# %%
cm = confusion_matrix(y_test,Y_pred)
accuracy = float(cm.diagonal().sum())/len(y_test)
print("\nSVM Accuracy: ", accuracy)

# %%
precision, recall, fscore, support = precision_recall_fscore_support(y_test, Y_pred, average='binary')
print('Precision = ',round(precision,4),'\nRecall = ', round(recall,4), '\nF-Score = ',round(fscore,4))

# %%
model = model.fit(X_train_scaled, y_train)
y_pred_ = model.predict(X_test_scaled)

# %%
precision, recall, fscore, support = precision_recall_fscore_support(y_test, y_pred_, average='binary')
print('Precision = ',round(precision,4),'\nRecall = ', round(recall,4), '\nF-Score = ',round(fscore,4))

# %%
cm = confusion_matrix(y_test,y_pred_)
accuracy = float(cm.diagonal().sum())/len(y_test)
print("\nSVM Accuracy: ", accuracy)

# %%
accuracy = accuracy_score(y_test,y_pred_)
conf_mat = confusion_matrix(y_test,y_pred_)
print("The accuracy of the model is :", round(accuracy,2)*100,"%")
print("Confusion Matrix:\n", conf_mat)

# %%
model.score(X_test,y_test)

# %% [markdown]
# ### Random Forest model

# %%
# work on Balanced DATA (Random sampling)
model = RandomForestClassifier(max_depth=3,random_state=2)

# %%
model = model.fit(X_train,y_kktrain)

# %%
model.score(X_test,y_test)

# %%
Y_pred = model.predict(X_test)

# %%
precision, recall, fscore, support = precision_recall_fscore_support(y_test, Y_pred, average='binary')
print('Precision = ',round(precision,4),'\nRecall = ', round(recall,4), '\nF-Score = ',round(fscore,4))

# %% [markdown]
# # Different Scales

# %%
#

# %% [markdown]
# # All Models

# %%
# Create Function to fit on All models and Calculat it's score, F1, Prec, Recall ... etc.
